# %%
# %pip install "transformers>=4.49.0" accelerate peft bitsandbytes datasets "qwen-vl-utils[decord]==0.0.8" "comet-ml>=3.31.0" "huggingface_hub[hf_xet]"
# Out:
# Requirement already satisfied: transformers>=4.49.0 in /usr/local/lib/python3.11/dist-packages (4.54.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.16.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.46.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: qwen-vl-utils==0.0.8 in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils[decord]==0.0.8) (0.0.8)
# Requirement already satisfied: comet-ml>=3.31.0 in /usr/local/lib/python3.11/dist-packages (3.50.0)
# Requirement already satisfied: huggingface_hub[hf_xet] in /usr/local/lib/python3.11/dist-packages (0.34.1)
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (15.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (25.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (11.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2.32.3)
# Requirement already satisfied: decord in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils[decord]==0.0.8) (0.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.49.0) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.49.0) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.49.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.49.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.49.0) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.49.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.49.0) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (0.23.2)
# Requirement already satisfied: everett<3.2.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml>=3.31.0) (3.1.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (4.25.0)
# Requirement already satisfied: python-box<7.0.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (6.1.0)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (1.0.0)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (13.9.4)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (2.33.2)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (3.20.1)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (1.17.2)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (1.1.5)
# Requirement already satisfied: configobj in /usr/local/lib/python3.11/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml>=3.31.0) (5.0.9)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.14)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.0) (0.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2025.7.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.2->comet-ml>=3.31.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.2->comet-ml>=3.31.0) (2.19.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet-ml>=3.31.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)

# %%
import os
import json
import PIL

# %%
# !nvidia-smi
# Out:
# Thu Jul 31 02:49:23 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0             47W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
# replace generated_diagrams/images/schema_0000.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A\
#   inflating: generated_diagrams/images/schema_0000.png
#   inflating: generated_diagrams/images/schema_0001.png
#   inflating: generated_diagrams/images/schema_0002.png
#   inflating: generated_diagrams/images/schema_0003.png
#   inflating: generated_diagrams/images/schema_0004.png
#   inflating: generated_diagrams/images/schema_0005.png
#   inflating: generated_diagrams/images/schema_0006.png
#   inflating: generated_diagrams/images/schema_0007.png
#   inflating: generated_diagrams/images/schema_0008.png
#   inflating: generated_diagrams/images/schema_0009.png
#   inflating: generated_diagrams/images/schema_0010.png
#   inflating: generated_diagrams/images/schema_0011.png
#   inflating: generated_diagrams/images/schema_0012.png
#   inflating: generated_diagrams/images/schema_0013.png
#   inflating: generated_diagrams/images/schema_0014.png
#   inflating: generated_diagrams/images/schema_0015.png
#   inflating: generated_diagrams/images/schema_0016.png
#   inflating: generated_diagrams/images/schema_0017.png
#   inflating: generated_diagrams/images/schema_0018.png
#   inflating: generated_diagrams/images/schema_0019.png
#   inflating: generated_diagrams/images/schema_0020.png
#   inflating: generated_diagrams/images/schema_0021.png
#   inflating: generated_diagrams/images/schema_0022.png
#   inflating: generated_diagrams/images/schema_0023.png
#   inflating: generated_diagrams/images/schema_0024.png
#   inflating: generated_diagrams/images/schema_0025.png
#   inflating: generated_diagrams/images/schema_0026.png
#   inflating: generated_diagrams/images/schema_0027.png
#   inflating: generated_diagrams/images/schema_0028.png
#   inflating: generated_diagrams/images/schema_0029.png
#   inflating: generated_diagrams/images/schema_0030.png
#   inflating: generated_diagrams/images/schema_0031.png
#   inflating: generated_diagrams/images/schema_0032.png
#   inflating: generated_diagrams/images/schema_0033.png
#   inflating: generated_diagrams/images/schema_0034.png
#   inflating: generated_diagrams/images/schema_0035.png
#   inflating: generated_diagrams/images/schema_0036.png
#   inflating: generated_diagrams/images/schema_0037.png
#   inflating: generated_diagrams/images/schema_0038.png
#   inflating: generated_diagrams/images/schema_0039.png
#   inflating: generated_diagrams/images/schema_0040.png
#   inflating: generated_diagrams/images/schema_0041.png
#   inflating: generated_diagrams/images/schema_0042.png
#   inflating: generated_diagrams/images/schema_0043.png
#   inflating: generated_diagrams/images/schema_0044.png
#   inflating: generated_diagrams/images/schema_0045.png
#   inflating: generated_diagrams/images/schema_0046.png
#   inflating: generated_diagrams/images/schema_0047.png
#   inflating: generated_diagrams/images/schema_0048.png
#   inflating: generated_diagrams/images/schema_0049.png
#   inflating: generated_diagrams/images/schema_0050.png
#   inflating: generated_diagrams/images/schema_0051.png
#   inflating: generated_diagrams/images/schema_0052.png
#   inflating: generated_diagrams/images/schema_0053.png
#   inflating: generated_diagrams/images/schema_0054.png
#   inflating: generated_diagrams/images/schema_0055.png
#   inflating: generated_diagrams/images/schema_0056.png
#   inflating: generated_diagrams/images/schema_0057.png
#   inflating: generated_diagrams/images/schema_0058.png
#   inflating: generated_diagrams/images/schema_0059.png
#   inflating: generated_diagrams/images/schema_0060.png
#   inflating: generated_diagrams/images/schema_0061.png
#   inflating: generated_diagrams/images/schema_0062.png
#   inflating: generated_diagrams/images/schema_0063.png
#   inflating: generated_diagrams/images/schema_0064.png
#   inflating: generated_diagrams/images/schema_0065.png
#   inflating: generated_diagrams/images/schema_0066.png
#   inflating: generated_diagrams/images/schema_0067.png
#   inflating: generated_diagrams/images/schema_0068.png
#   inflating: generated_diagrams/images/schema_0069.png
#   inflating: generated_diagrams/images/schema_0070.png
#   inflating: generated_diagrams/images/schema_0071.png
#   inflating: generated_diagrams/images/schema_0072.png
#   inflating: generated_diagrams/images/schema_0073.png
#   inflating: generated_diagrams/images/schema_0074.png
#   inflating: generated_diagrams/images/schema_0075.png
#   inflating: generated_diagrams/images/schema_0076.png
#   inflating: generated_diagrams/images/schema_0077.png
#   inflating: generated_diagrams/images/schema_0078.png
#   inflating: generated_diagrams/images/schema_0079.png
#   inflating: generated_diagrams/images/schema_0080.png
#   inflating: generated_diagrams/images/schema_0081.png
#   inflating: generated_diagrams/images/schema_0082.png
#   inflating: generated_diagrams/images/schema_0083.png
#   inflating: generated_diagrams/images/schema_0084.png
#   inflating: generated_diagrams/images/schema_0085.png
#   inflating: generated_diagrams/images/schema_0086.png
#   inflating: generated_diagrams/images/schema_0087.png
#   inflating: generated_diagrams/images/schema_0088.png
#   inflating: generated_diagrams/images/schema_0089.png
#   inflating: generated_diagrams/images/schema_0090.png
#   inflating: generated_diagrams/images/schema_0091.png
#   inflating: generated_diagrams/images/schema_0092.png
#   inflating: generated_diagrams/images/schema_0093.png
#   inflating: generated_diagrams/images/schema_0094.png
#   inflating: generated_diagrams/images/schema_0095.png
#   inflating: generated_diagrams/images/schema_0096.png
#   inflating: generated_diagrams/images/schema_0097.png
#   inflating: generated_diagrams/images/schema_0098.png
#   inflating: generated_diagrams/images/schema_0099.png
#   inflating: generated_diagrams/images/schema_0100.png
#   inflating: generated_diagrams/images/schema_0101.png
#   inflating: generated_diagrams/images/schema_0102.png
#   inflating: generated_diagrams/images/schema_0103.png
#   inflating: generated_diagrams/images/schema_0104.png
#   inflating: generated_diagrams/images/schema_0105.png
#   inflating: generated_diagrams/images/schema_0106.png
#   inflating: generated_diagrams/images/schema_0107.png
#   inflating: generated_diagrams/images/schema_0108.png
#   inflating: generated_diagrams/images/schema_0109.png
#   inflating: generated_diagrams/images/schema_0110.png
#   inflating: generated_diagrams/images/schema_0111.png
#   inflating: generated_diagrams/images/schema_0112.png
#   inflating: generated_diagrams/images/schema_0113.png
#   inflating: generated_diagrams/images/schema_0114.png
#   inflating: generated_diagrams/images/schema_0115.png
#   inflating: generated_diagrams/images/schema_0116.png
#
#   inflating: generated_diagrams/images/schema_0117.png
#   inflating: generated_diagrams/images/schema_0118.png
#   inflating: generated_diagrams/images/schema_0119.png
#   inflating: generated_diagrams/images/schema_0120.png
#   inflating: generated_diagrams/images/schema_0121.png
#   inflating: generated_diagrams/images/schema_0122.png
#   inflating: generated_diagrams/images/schema_0123.png
#   inflating: generated_diagrams/images/schema_0124.png
#   inflating: generated_diagrams/images/schema_0125.png
#   inflating: generated_diagrams/images/schema_0126.png
#   inflating: generated_diagrams/images/schema_0127.png
#   inflating: generated_diagrams/images/schema_0128.png
#   inflating: generated_diagrams/images/schema_0129.png
#   inflating: generated_diagrams/images/schema_0130.png
#   inflating: generated_diagrams/images/schema_0131.png
#   inflating: generated_diagrams/images/schema_0132.png
#   inflating: generated_diagrams/images/schema_0133.png
#   inflating: generated_diagrams/images/schema_0134.png
#   inflating: generated_diagrams/images/schema_0135.png
#   inflating: generated_diagrams/images/schema_0136.png
#   inflating: generated_diagrams/images/schema_0137.png
#   inflating: generated_diagrams/images/schema_0138.png
#   inflating: generated_diagrams/images/schema_0139.png
#   inflating: generated_diagrams/images/schema_0140.png
#   inflating: generated_diagrams/images/schema_0141.png
#   inflating: generated_diagrams/images/schema_0142.png
#   inflating: generated_diagrams/images/schema_0143.png
#   inflating: generated_diagrams/images/schema_0144.png
#   inflating: generated_diagrams/images/schema_0145.png
#   inflating: generated_diagrams/images/schema_0146.png
#   inflating: generated_diagrams/images/schema_0147.png
#   inflating: generated_diagrams/images/schema_0148.png
#   inflating: generated_diagrams/images/schema_0149.png
#   inflating: generated_diagrams/images/schema_0150.png
#   inflating: generated_diagrams/images/schema_0151.png
#   inflating: generated_diagrams/images/schema_0152.png
#   inflating: generated_diagrams/images/schema_0153.png
#   inflating: generated_diagrams/images/schema_0154.png
#   inflating: generated_diagrams/images/schema_0155.png
#   inflating: generated_diagrams/images/schema_0156.png
#   inflating: generated_diagrams/images/schema_0157.png
#   inflating: generated_diagrams/images/schema_0158.png
#   inflating: generated_diagrams/images/schema_0159.png
#   inflating: generated_diagrams/images/schema_0160.png
#   inflating: generated_diagrams/images/schema_0161.png
#   inflating: generated_diagrams/images/schema_0162.png
#   inflating: generated_diagrams/images/schema_0163.png
#   inflating: generated_diagrams/images/schema_0164.png
#   inflating: generated_diagrams/images/schema_0165.png
#   inflating: generated_diagrams/images/schema_0166.png
#   inflating: generated_diagrams/images/schema_0167.png
#   inflating: generated_diagrams/images/schema_0168.png
#   inflating: generated_diagrams/images/schema_0169.png
#   inflating: generated_diagrams/images/schema_0170.png
#   inflating: generated_diagrams/images/schema_0171.png
#   inflating: generated_diagrams/images/schema_0172.png
#   inflating: generated_diagrams/images/schema_0173.png
#   inflating: generated_diagrams/images/schema_0174.png
#   inflating: generated_diagrams/images/schema_0175.png
#   inflating: generated_diagrams/images/schema_0176.png
#   inflating: generated_diagrams/images/schema_0177.png
#   inflating: generated_diagrams/images/schema_0178.png
#   inflating: generated_diagrams/images/schema_0179.png
#   inflating: generated_diagrams/images/schema_0180.png
#   inflating: generated_diagrams/images/schema_0181.png
#   inflating: generated_diagrams/images/schema_0182.png
#   inflating: generated_diagrams/images/schema_0183.png
#   inflating: generated_diagrams/images/schema_0184.png
#   inflating: generated_diagrams/images/schema_0185.png
#   inflating: generated_diagrams/images/schema_0186.png
#   inflating: generated_diagrams/images/schema_0187.png
#   inflating: generated_diagrams/images/schema_0188.png
#   inflating: generated_diagrams/images/schema_0189.png
#   inflating: generated_diagrams/images/schema_0190.png
#   inflating: generated_diagrams/images/schema_0191.png
#   inflating: generated_diagrams/images/schema_0193.png
#   inflating: generated_diagrams/images/schema_0194.png
#   inflating: generated_diagrams/images/schema_0195.png
#   inflating: generated_diagrams/images/schema_0196.png
#   inflating: generated_diagrams/images/schema_0197.png
#   inflating: generated_diagrams/images/schema_0198.png
#   inflating: generated_diagrams/images/schema_0199.png
#   inflating: generated_diagrams/images/schema_0200.png
#   inflating: generated_diagrams/images/schema_0201.png
#   inflating: generated_diagrams/images/schema_0202.png
#   inflating: generated_diagrams/images/schema_0203.png
#   inflating: generated_diagrams/images/schema_0204.png
#   inflating: generated_diagrams/images/schema_0205.png
#   inflating: generated_diagrams/images/schema_0206.png
#   inflating: generated_diagrams/images/schema_0207.png
#   inflating: generated_diagrams/images/schema_0208.png
#   inflating: generated_diagrams/images/schema_0209.png
#   inflating: generated_diagrams/images/schema_0210.png
#   inflating: generated_diagrams/images/schema_0211.png
#   inflating: generated_diagrams/images/schema_0212.png
#   inflating: generated_diagrams/images/schema_0213.png
#   inflating: generated_diagrams/images/schema_0214.png
#   inflating: generated_diagrams/images/schema_0215.png
#   inflating: generated_diagrams/images/schema_0216.png
#   inflating: generated_diagrams/images/schema_0217.png
#   inflating: generated_diagrams/images/schema_0218.png
#   inflating: generated_diagrams/images/schema_0219.png
#   inflating: generated_diagrams/images/schema_0220.png
#   inflating: generated_diagrams/images/schema_0221.png
#   inflating: generated_diagrams/images/schema_0222.png
#   inflating: generated_diagrams/images/schema_0223.png
#   inflating: generated_diagrams/images/schema_0224.png
#   inflating: generated_diagrams/images/schema_0225.png
#   inflating: generated_diagrams/images/schema_0226.png
#   inflating: generated_diagrams/images/schema_0227.png
#   inflating: generated_diagrams/images/schema_0228.png
#   inflating: generated_diagrams/images/schema_0229.png
#   inflating: generated_diagrams/images/schema_0230.png
#   inflating: generated_diagrams/images/schema_0231.png
#   inflating: generated_diagrams/images/schema_0232.png
#   inflating: generated_diagrams/images/schema_0233.png
#   inflating: generated_diagrams/images/schema_0234.png
#   inflating: generated_diagrams/images/schema_0235.png
#   inflating: generated_diagrams/images/schema_0236.png
#   inflating: generated_diagrams/images/schema_0237.png
#   inflating: generated_diagrams/images/schema_0238.png
#   inflating: generated_diagrams/images/schema_0239.png
#   inflating: generated_diagrams/images/schema_0240.png
#   inflating: generated_diagrams/images/schema_0241.png
#   inflating: generated_diagrams/images/schema_0242.png
#   inflating: generated_diagrams/images/schema_0243.png
#   inflating: generated_diagrams/images/schema_0244.png
#   inflating: generated_diagrams/images/schema_0245.png
#   inflating: generated_diagrams/images/schema_0246.png
#   inflating: generated_diagrams/images/schema_0247.png
#   inflating: generated_diagrams/images/schema_0248.png
#   inflating: generated_diagrams/images/schema_0249.png
#   inflating: generated_diagrams/images/schema_0250.png
#   inflating: generated_diagrams/images/schema_0251.png
#   inflating: generated_diagrams/images/schema_0252.png
#   inflating: generated_diagrams/images/schema_0253.png
#   inflating: generated_diagrams/images/schema_0254.png
#   inflating: generated_diagrams/images/schema_0255.png
#   inflating: generated_diagrams/images/schema_0256.png
#   inflating: generated_diagrams/images/schema_0257.png
#   inflating: generated_diagrams/images/schema_0258.png
#   inflating: generated_diagrams/images/schema_0259.png
#   inflating: generated_diagrams/images/schema_0260.png
#   inflating: generated_diagrams/images/schema_0261.png
#   inflating: generated_diagrams/images/schema_0262.png
#   inflating: generated_diagrams/images/schema_0263.png
#   inflating: generated_diagrams/images/schema_0264.png
#   inflating: generated_diagrams/images/schema_0265.png
#   inflating: generated_diagrams/images/schema_0266.png
#   inflating: generated_diagrams/images/schema_0267.png
#   inflating: generated_diagrams/images/schema_0268.png
#   inflating: generated_diagrams/images/schema_0269.png
#   inflating: generated_diagrams/images/schema_0270.png
#   inflating: generated_diagrams/images/schema_0271.png
#   inflating: generated_diagrams/images/schema_0272.png
#   inflating: generated_diagrams/images/schema_0273.png
#   inflating: generated_diagrams/images/schema_0274.png
#   inflating: generated_diagrams/images/schema_0275.png
#   inflating: generated_diagrams/images/schema_0276.png
#   inflating: generated_diagrams/images/schema_0277.png
#   inflating: generated_diagrams/images/schema_0278.png
#   inflating: generated_diagrams/images/schema_0279.png
#   inflating: generated_diagrams/images/schema_0280.png
#   inflating: generated_diagrams/images/schema_0281.png
#   inflating: generated_diagrams/images/schema_0282.png
#   inflating: generated_diagrams/images/schema_0283.png
#   inflating: generated_diagrams/images/schema_0284.png
#   inflating: generated_diagrams/images/schema_0285.png
#   inflating: generated_diagrams/images/schema_0286.png
#   inflating: generated_diagrams/images/schema_0287.png
#   inflating: generated_diagrams/images/schema_0288.png
#   inflating: generated_diagrams/images/schema_0289.png
#   inflating: generated_diagrams/images/schema_0290.png
#   inflating: generated_diagrams/images/schema_0291.png
#   inflating: generated_diagrams/images/schema_0292.png
#   inflating: generated_diagrams/images/schema_0293.png
#   inflating: generated_diagrams/images/schema_0294.png
#   inflating: generated_diagrams/images/schema_0295.png
#   inflating: generated_diagrams/images/schema_0296.png
#   inflating: generated_diagrams/images/schema_0297.png
#   inflating: generated_diagrams/images/schema_0298.png
#   inflating: generated_diagrams/images/schema_0299.png
#   inflating: generated_diagrams/images/schema_0300.png
#   inflating: generated_diagrams/images/schema_0301.png
#   inflating: generated_diagrams/images/schema_0302.png
#   inflating: generated_diagrams/images/schema_0303.png
#   inflating: generated_diagrams/images/schema_0304.png
#   inflating: generated_diagrams/images/schema_0305.png
#   inflating: generated_diagrams/images/schema_0306.png
#   inflating: generated_diagrams/images/schema_0307.png
#   inflating: generated_diagrams/images/schema_0308.png
#   inflating: generated_diagrams/images/schema_0309.png
#   inflating: generated_diagrams/images/schema_0310.png
#   inflating: generated_diagrams/images/schema_0311.png
#   inflating: generated_diagrams/images/schema_0312.png
#   inflating: generated_diagrams/images/schema_0313.png
#   inflating: generated_diagrams/images/schema_0314.png
#   inflating: generated_diagrams/images/schema_0315.png
#   inflating: generated_diagrams/images/schema_0316.png
#   inflating: generated_diagrams/images/schema_0317.png
#   inflating: generated_diagrams/images/schema_0318.png
#   inflating: generated_diagrams/images/schema_0319.png
#   inflating: generated_diagrams/images/schema_0320.png
#   inflating: generated_diagrams/images/schema_0321.png
#   inflating: generated_diagrams/images/schema_0322.png
#   inflating: generated_diagrams/images/schema_0323.png
#   inflating: generated_diagrams/images/schema_0324.png
#   inflating: generated_diagrams/images/schema_0325.png
#   inflating: generated_diagrams/images/schema_0326.png
#   inflating: generated_diagrams/images/schema_0327.png
#   inflating: generated_diagrams/images/schema_0328.png
#   inflating: generated_diagrams/images/schema_0329.png
#   inflating: generated_diagrams/images/schema_0330.png
#   inflating: generated_diagrams/images/schema_0331.png
#   inflating: generated_diagrams/images/schema_0332.png
#   inflating: generated_diagrams/images/schema_0333.png
#   inflating: generated_diagrams/images/schema_0334.png
#   inflating: generated_diagrams/images/schema_0335.png
#   inflating: generated_diagrams/images/schema_0336.png
#   inflating: generated_diagrams/images/schema_0337.png
#   inflating: generated_diagrams/images/schema_0338.png
#   inflating: generated_diagrams/images/schema_0339.png
#   inflating: generated_diagrams/images/schema_0340.png
#   inflating: generated_diagrams/images/schema_0341.png
#   inflating: generated_diagrams/images/schema_0342.png
#   inflating: generated_diagrams/images/schema_0343.png
#   inflating: generated_diagrams/images/schema_0344.png
#   inflating: generated_diagrams/images/schema_0345.png
#   inflating: generated_diagrams/images/schema_0346.png
#   inflating: generated_diagrams/images/schema_0347.png
#   inflating: generated_diagrams/images/schema_0348.png
#   inflating: generated_diagrams/images/schema_0349.png
#   inflating: generated_diagrams/images/schema_0350.png
#   inflating: generated_diagrams/images/schema_0351.png
#   inflating: generated_diagrams/images/schema_0352.png
#   inflating: generated_diagrams/images/schema_0353.png
#   inflating: generated_diagrams/images/schema_0354.png
#   inflating: generated_diagrams/images/schema_0355.png
#   inflating: generated_diagrams/images/schema_0356.png
#   inflating: generated_diagrams/images/schema_0357.png
#   inflating: generated_diagrams/images/schema_0358.png
#   inflating: generated_diagrams/images/schema_0359.png
#   inflating: generated_diagrams/images/schema_0360.png
#   inflating: generated_diagrams/images/schema_0361.png
#   inflating: generated_diagrams/images/schema_0362.png
#   inflating: generated_diagrams/images/schema_0363.png
#   inflating: generated_diagrams/images/schema_0364.png
#   inflating: generated_diagrams/images/schema_0365.png
#   inflating: generated_diagrams/images/schema_0366.png
#   inflating: generated_diagrams/images/schema_0367.png
#   inflating: generated_diagrams/images/schema_0368.png
#   inflating: generated_diagrams/images/schema_0369.png
#   inflating: generated_diagrams/images/schema_0370.png
#   inflating: generated_diagrams/images/schema_0371.png
#   inflating: generated_diagrams/images/schema_0372.png
#   inflating: generated_diagrams/images/schema_0373.png
#   inflating: generated_diagrams/images/schema_0374.png
#   inflating: generated_diagrams/images/schema_0375.png
#   inflating: generated_diagrams/images/schema_0376.png
#   inflating: generated_diagrams/images/schema_0377.png
#   inflating: generated_diagrams/images/schema_0378.png
#   inflating: generated_diagrams/images/schema_0379.png
#   inflating: generated_diagrams/images/schema_0380.png
#   inflating: generated_diagrams/images/schema_0381.png
#   inflating: generated_diagrams/images/schema_0382.png
#   inflating: generated_diagrams/images/schema_0383.png
#   inflating: generated_diagrams/images/schema_0384.png
#   inflating: generated_diagrams/images/schema_0385.png
#   inflating: generated_diagrams/images/schema_0386.png
#   inflating: generated_diagrams/images/schema_0387.png
#   inflating: generated_diagrams/images/schema_0388.png
#   inflating: generated_diagrams/images/schema_0389.png
#   inflating: generated_diagrams/images/schema_0390.png
#   inflating: generated_diagrams/images/schema_0391.png
#   inflating: generated_diagrams/images/schema_0392.png
#   inflating: generated_diagrams/images/schema_0393.png
#   inflating: generated_diagrams/images/schema_0394.png
#   inflating: generated_diagrams/images/schema_0395.png
#   inflating: generated_diagrams/images/schema_0396.png
#   inflating: generated_diagrams/images/schema_0397.png
#   inflating: generated_diagrams/images/schema_0398.png
#   inflating: generated_diagrams/images/schema_0399.png
#   inflating: generated_diagrams/images/schema_0400.png
#   inflating: generated_diagrams/images/schema_0401.png
#   inflating: generated_diagrams/training_dataset.json

# %%
import json
from pathlib import Path

# Load real schema dataset from training.py approach
dataset_file = Path("/content/generated_diagrams/training_dataset.json")

if not dataset_file.exists():
    print(f"❌ Dataset not found: {dataset_file}")
    print("Please create the dataset first using your data generation script.")
else:
    print(f"✅ Using dataset: {dataset_file}")
    with open(dataset_file, 'r') as f:
        real_data = json.load(f)

    print(f"Loaded {len(real_data)} samples from real schema dataset")
# Out:
# ✅ Using dataset: /content/generated_diagrams/training_dataset.json
# Loaded 402 samples from real schema dataset

# %%
print(f"Real schema dataset contains {len(real_data)} samples")
print(f"Sample keys: {list(real_data[0].keys()) if real_data else 'No data'}")
if real_data:
    print(f"First sample structure:")
    for key, value in real_data[0].items():
        print(f"  {key}: {type(value).__name__}")
        if key == 'schema_json' and isinstance(value, dict):
            print(f"    schema_json keys: {list(value.keys())}")
        elif key == 'image':
            print(f"    image path: {value}")
# Out:
# Real schema dataset contains 402 samples
# Sample keys: ['id', 'image', 'schema_json', 'sql_output', 'domain', 'source', 'num_tables', 'num_relationships']
# First sample structure:
#   id: int
#   image: str
#     image path: real_diagrams\images\schema_0000.png
#   schema_json: dict
#     schema_json keys: ['domain', 'source', 'tables', 'relationships']
#   sql_output: str
#   domain: str
#   source: str
#   num_tables: int
#   num_relationships: int

# %%
if real_data:
    print("First sample from real schema dataset:")
    sample = real_data[0]
    print(f"Image path: {sample['image']}")
    print(f"Schema JSON keys: {list(sample['schema_json'].keys())}")
    print(f"Schema JSON preview:")
    print(json.dumps(sample['schema_json'], indent=2)[:500] + "...")
# Out:
# First sample from real schema dataset:
# Image path: real_diagrams\images\schema_0000.png
# Schema JSON keys: ['domain', 'source', 'tables', 'relationships']
# Schema JSON preview:
# {
#   "domain": "school",
#   "source": "programmatic",
#   "tables": [
#     {
#       "name": "students",
#       "columns": [
#         {
#           "name": "id",
#           "type": "INTEGER",
#           "primary_key": true
#         },
#         {
#           "name": "date_of_birth",
#           "type": "DATE"
#         },
#         {
#           "name": "email",
#           "type": "VARCHAR(255)",
#           "unique": true
#         },
#         {
#           "name": "is_active",
#           "type": "BOOLEAN",
#           "default": ...

# %%
SYSTEM_MESSAGE = """You are a Vision Language Model specialized in extracting structured database schema information from ER diagrams.

Your task is to analyze the provided database schema diagram and extract the complete schema information into a well-structured JSON format.

The diagram shows tables with their columns, data types, primary keys, foreign keys, and relationships between tables.

Focus on identifying:
1. All table names accurately
2. All column names and their data types
3. Primary keys
4. Foreign key relationships between tables
5. Data constraints (NOT NULL, UNIQUE, DEFAULT values)

Provide only the JSON output based on the extracted information. Avoid additional explanations or comments."""

# %%
def format_data(entry):
    return [
        {
            "role": "system",
            "content": [{"type": "text", "text": SYSTEM_MESSAGE}],
        },
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    # Load PIL image from path for real schema data
                    "image": entry["image"] if isinstance(entry["image"], str) else entry["image"],
                },
                {
                    "type": "text",
                    "text": "Extract data in JSON format",
                },
            ],
        },
        {
            "role": "assistant",
            "content": [{"type": "text", "text": json.dumps(entry["schema_json"], ensure_ascii=False)}],
        },
    ]

# %%
# Split real schema data into train/eval sets
import random
random.seed(42)

# Calculate split sizes (similar to training.py)
total_size = len(real_data)
train_split = 0.8
val_split = 0.2

train_size = int(train_split * total_size)
val_size = total_size - train_size

# Shuffle and split
shuffled_data = real_data.copy()
random.shuffle(shuffled_data)

train_data = shuffled_data[:train_size]
eval_data = shuffled_data[train_size:]

print(f"Dataset splits:")
print(f"  Total: {total_size} samples")
print(f"  Train: {len(train_data)} samples")
print(f"  Eval: {len(eval_data)} samples")
# Out:
# Dataset splits:
#   Total: 402 samples
#   Train: 321 samples
#   Eval: 81 samples

# %%
from PIL import Image
import os
from pathlib import Path

def load_real_schema_data(data_list):
    """Load and format real schema data with proper image handling"""
    formatted_data = []

    for entry in data_list:
        # Handle image loading like in training.py
        image_path = entry['image']
        if not os.path.exists(image_path):
            # Convert Windows path separators and handle relative paths
            image_path = image_path.replace('\\', '/')
            if not os.path.exists(image_path):
                # Try relative to project directory
                image_path =  Path("generated_diagrams") / "images" / Path(image_path).name

        try:
            image = Image.open(image_path).convert('RGB')
            # Create new entry with loaded image
            entry_with_image = entry.copy()
            entry_with_image['image'] = image
            formatted_data.append((entry_with_image, format_data(entry_with_image)))
        except Exception as e:
            print(f"Error loading image {image_path}: {e}")
            # Create a dummy white image as fallback
            image = Image.new('RGB', (800, 600), color='white')
            entry_with_image = entry.copy()
            entry_with_image['image'] = image
            formatted_data.append((entry_with_image, format_data(entry_with_image)))

    return formatted_data

train_dataset = load_real_schema_data(train_data)
eval_dataset = load_real_schema_data(eval_data)

print(f"Formatted train dataset: {len(train_dataset)} samples")
print(f"Formatted eval dataset: {len(eval_dataset)} samples")
# Out:
# Formatted train dataset: 321 samples
# Formatted eval dataset: 81 samples

# %%
# 2 values, first value is dataset entry, the second one is the chat template with dataset applied
train_dataset[0]
# Out:
# ({'id': 151,
#   'image': <PIL.Image.Image image mode=RGB size=784x1213>,
#   'schema_json': {'domain': 'school',
#    'source': 'programmatic',
#    'tables': [{'name': 'students',
#      'columns': [{'name': 'id', 'type': 'INTEGER', 'primary_key': True},
#       {'name': 'created_at',
#        'type': 'TIMESTAMP',
#        'default': 'CURRENT_TIMESTAMP'},
#       {'name': 'address', 'type': 'TEXT'},
#       {'name': 'name', 'type': 'VARCHAR(255)', 'nullable': False}]},
#     {'name': 'teachers',
#      'columns': [{'name': 'id', 'type': 'INTEGER', 'primary_key': True},
#       {'name': 'status', 'type': 'VARCHAR(50)', 'default': "'active'"},
#       {'name': 'date_of_birth', 'type': 'DATE'},
#       {'name': 'description', 'type': 'TEXT'},
#       {'name': 'is_active', 'type': 'BOOLEAN', 'default': 'true'}]},
#     {'name': 'courses',
#      'columns': [{'name': 'id', 'type': 'INTEGER', 'primary_key': True},
#       {'name': 'rating', 'type': 'FLOAT'},
#       {'name': 'salary', 'type': 'DECIMAL(12,2)'},
#       {'name': 'phone', 'type': 'VARCHAR(20)'},
#       {'name': 'quantity', 'type': 'INTEGER', 'default': 0},
#       {'name': 'status', 'type': 'VARCHAR(50)', 'default': "'active'"},
#       {'name': 'teacher_id', 'type': 'INTEGER', 'nullable': False},
#       {'name': 'department_id', 'type': 'INTEGER', 'nullable': False}]},
#     {'name': 'enrollments',
#      'columns': [{'name': 'id', 'type': 'INTEGER', 'primary_key': True},
#       {'name': 'salary', 'type': 'DECIMAL(12,2)'},
#       {'name': 'status', 'type': 'VARCHAR(50)', 'default': "'active'"},
#       {'name': 'date_of_birth', 'type': 'DATE'},
#       {'name': 'student_id', 'type': 'INTEGER', 'nullable': False},
#       {'name': 'course_id', 'type': 'INTEGER', 'nullable': False}]},
#     {'name': 'grades',
#      'columns': [{'name': 'id', 'type': 'INTEGER', 'primary_key': True},
#       {'name': 'date_of_birth', 'type': 'DATE'},
#       {'name': 'description', 'type': 'TEXT'},
#       {'name': 'address', 'type': 'TEXT'},
#       {'name': 'phone', 'type': 'VARCHAR(20)'},
#       {'name': 'enrollment_id', 'type': 'INTEGER', 'nullable': False}]},
#     {'name': 'departments',
#      'columns': [{'name': 'id', 'type': 'INTEGER', 'primary_key': True},
#       {'name': 'address', 'type': 'TEXT'},
#       {'name': 'updated_at',
#        'type': 'TIMESTAMP',
#        'default': 'CURRENT_TIMESTAMP'},
#       {'name': 'salary', 'type': 'DECIMAL(12,2)'},
#       {'name': 'description', 'type': 'TEXT'}]}],
#    'relationships': [{'from_table': 'enrollments',
#      'to_table': 'students',
#      'from_column': 'student_id',
#      'to_column': 'id',
#      'type': 'many_to_one'},
#     {'from_table': 'enrollments',
#      'to_table': 'courses',
#      'from_column': 'course_id',
#      'to_column': 'id',
#      'type': 'many_to_one'},
#     {'from_table': 'grades',
#      'to_table': 'enrollments',
#      'from_column': 'enrollment_id',
#      'to_column': 'id',
#      'type': 'many_to_one'},
#     {'from_table': 'courses',
#      'to_table': 'teachers',
#      'from_column': 'teacher_id',
#      'to_column': 'id',
#      'type': 'many_to_one'},
#     {'from_table': 'courses',
#      'to_table': 'departments',
#      'from_column': 'department_id',
#      'to_column': 'id',
#      'type': 'many_to_one'}]},
#   'sql_output': "CREATE TABLE students (\n    id INTEGER,\n    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,\n    address TEXT,\n    name VARCHAR(255) NOT NULL\n);\n\nCREATE TABLE teachers (\n    id INTEGER,\n    status VARCHAR(50) DEFAULT 'active',\n    date_of_birth DATE,\n    description TEXT,\n    is_active BOOLEAN DEFAULT true\n);\n\nCREATE TABLE courses (\n    id INTEGER,\n    rating FLOAT,\n    salary DECIMAL(12,2),\n    phone VARCHAR(20),\n    quantity INTEGER,\n    status VARCHAR(50) DEFAULT 'active',\n    teacher_id INTEGER NOT NULL,\n    department_id INTEGER NOT NULL\n);\n\nCREATE TABLE enrollments (\n    id INTEGER,\n    salary DECIMAL(12,2),\n    status VARCHAR(50) DEFAULT 'active',\n    date_of_birth DATE,\n    student_id INTEGER NOT NULL,\n    course_id INTEGER NOT NULL\n);\n\nCREATE TABLE grades (\n    id INTEGER,\n    date_of_birth DATE,\n    description TEXT,\n    address TEXT,\n    phone VARCHAR(20),\n    enrollment_id INTEGER NOT NULL\n);\n\nCREATE TABLE departments (\n    id INTEGER,\n    address TEXT,\n    updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,\n    salary DECIMAL(12,2),\n    description TEXT\n);\n\nALTER TABLE enrollments ADD FOREIGN KEY (student_id) REFERENCES students(id);\n\nALTER TABLE enrollments ADD FOREIGN KEY (course_id) REFERENCES courses(id);\n\nALTER TABLE grades ADD FOREIGN KEY (enrollment_id) REFERENCES enrollments(id);\n\nALTER TABLE courses ADD FOREIGN KEY (teacher_id) REFERENCES teachers(id);\n\nALTER TABLE courses ADD FOREIGN KEY (department_id) REFERENCES departments(id);",
#   'domain': 'school',
#   'source': 'programmatic',
#   'num_tables': 6,
#   'num_relationships': 5},
#  [{'role': 'system',
#    'content': [{'type': 'text',
#      'text': 'You are a Vision Language Model specialized in extracting structured database schema information from ER diagrams.\n\nYour task is to analyze the provided database schema diagram and extract the complete schema information into a well-structured JSON format.\n\nThe diagram shows tables with their columns, data types, primary keys, foreign keys, and relationships between tables.\n\nFocus on identifying:\n1. All table names accurately\n2. All column names and their data types\n3. Primary keys \n4. Foreign key relationships between tables\n5. Data constraints (NOT NULL, UNIQUE, DEFAULT values)\n\nProvide only the JSON output based on the extracted information. Avoid additional explanations or comments.'}]},
#   {'role': 'user',
#    'content': [{'type': 'image',
#      'image': <PIL.Image.Image image mode=RGB size=784x1213>},
#     {'type': 'text', 'text': 'Extract data in JSON format'}]},
#   {'role': 'assistant',
#    'content': [{'type': 'text',
#      'text': '{"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"name": "created_at", "type": "TIMESTAMP", "default": "CURRENT_TIMESTAMP"}, {"name": "address", "type": "TEXT"}, {"name": "name", "type": "VARCHAR(255)", "nullable": false}]}, {"name": "teachers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"name": "status", "type": "VARCHAR(50)", "default": "\'active\'"}, {"name": "date_of_birth", "type": "DATE"}, {"name": "description", "type": "TEXT"}, {"name": "is_active", "type": "BOOLEAN", "default": "true"}]}, {"name": "courses", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"name": "rating", "type": "FLOAT"}, {"name": "salary", "type": "DECIMAL(12,2)"}, {"name": "phone", "type": "VARCHAR(20)"}, {"name": "quantity", "type": "INTEGER", "default": 0}, {"name": "status", "type": "VARCHAR(50)", "default": "\'active\'"}, {"name": "teacher_id", "type": "INTEGER", "nullable": false}, {"name": "department_id", "type": "INTEGER", "nullable": false}]}, {"name": "enrollments", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"name": "salary", "type": "DECIMAL(12,2)"}, {"name": "status", "type": "VARCHAR(50)", "default": "\'active\'"}, {"name": "date_of_birth", "type": "DATE"}, {"name": "student_id", "type": "INTEGER", "nullable": false}, {"name": "course_id", "type": "INTEGER", "nullable": false}]}, {"name": "grades", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"name": "date_of_birth", "type": "DATE"}, {"name": "description", "type": "TEXT"}, {"name": "address", "type": "TEXT"}, {"name": "phone", "type": "VARCHAR(20)"}, {"name": "enrollment_id", "type": "INTEGER", "nullable": false}]}, {"name": "departments", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"name": "address", "type": "TEXT"}, {"name": "updated_at", "type": "TIMESTAMP", "default": "CURRENT_TIMESTAMP"}, {"name": "salary", "type": "DECIMAL(12,2)"}, {"name": "description", "type": "TEXT"}]}], "relationships": [{"from_table": "enrollments", "to_table": "students", "from_column": "student_id", "to_column": "id", "type": "many_to_one"}, {"from_table": "enrollments", "to_table": "courses", "from_column": "course_id", "to_column": "id", "type": "many_to_one"}, {"from_table": "grades", "to_table": "enrollments", "from_column": "enrollment_id", "to_column": "id", "type": "many_to_one"}, {"from_table": "courses", "to_table": "teachers", "from_column": "teacher_id", "to_column": "id", "type": "many_to_one"}, {"from_table": "courses", "to_table": "departments", "from_column": "department_id", "to_column": "id", "type": "many_to_one"}]}'}]}])

# %%
import torch
from peft import get_peft_model, LoraConfig
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor

# Using same model as training.py
MODEL_ID = "Qwen/Qwen2.5-VL-3B-Instruct"

lora_config = LoraConfig(
    lora_alpha=32,
    lora_dropout=0.1,
    r=16,
    bias="none",
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
    task_type="CAUSAL_LM",
)

model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 7,372,800 || all params: 3,761,995,776 || trainable%: 0.1960

# %%
MAX_PIXELS = 256 * 28 * 28
MIN_PIXELS = 128 * 28 * 28

processor = AutoProcessor.from_pretrained(
    MODEL_ID, min_pixels=MIN_PIXELS, max_pixels=MAX_PIXELS
)
# Out:
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.

# %%
from qwen_vl_utils import process_vision_info

def training_collate_fn(batch):
    """Collate function based on training.py approach"""
    # Get only the formatted data (second element of tuple)
    _, formatted_data = zip(*batch)

    # Apply chat template to get texts
    texts = [processor.apply_chat_template(entry) for entry in formatted_data]

    # Process vision info to get images
    image_inputs = [
        process_vision_info(entry)[0]  # Only takes the PIL image
        for entry in formatted_data
    ]

    # Process with Qwen2VL processor
    model_inputs = processor(
        text=texts,
        images=image_inputs,
        padding=True,
        return_tensors="pt",
    )

    labels = model_inputs["input_ids"].clone()  # Clone for masking

    # Mask system message and image token IDs in labels (key part from training.py)
    for i, example in enumerate(formatted_data):
        sysuser_conv = example[:-1]  # Remove assistant response
        sysuser_text = processor.apply_chat_template(sysuser_conv, tokenize=False)
        sysuser_img, _ = process_vision_info(sysuser_conv)

        sysuser_inputs = processor(
            text=[sysuser_text],
            images=[sysuser_img],
            return_tensors="pt",
            padding=True,
        )

        sysuser_len = sysuser_inputs["input_ids"].shape[1]
        labels[i, :sysuser_len] = -100  # Mask input tokens

    return {
        'input_ids': model_inputs["input_ids"],
        'attention_mask': model_inputs["attention_mask"],
        'pixel_values': model_inputs["pixel_values"],
        'image_grid_thw': model_inputs["image_grid_thw"],
        'labels': labels
    }

# %%
def evaluating_collate_fn(batch):
    """Evaluation collate function based on training.py"""
    data, formatted_data = zip(*batch)
    ground_truth = [json.dumps(entry["schema_json"], ensure_ascii=False) for entry in data]

    # Remove assistant answer for evaluation
    formatted_data = [entry[:2] for entry in formatted_data]

    texts = [
        processor.apply_chat_template(entry, tokenize=False) for entry in formatted_data
    ]

    image_inputs = [process_vision_info(entry)[0] for entry in formatted_data]

    model_inputs = processor(
        text=texts,
        images=image_inputs,
        return_tensors="pt",
        padding=True,
    )

    return {
        'input_ids': model_inputs["input_ids"],
        'attention_mask': model_inputs["attention_mask"],
        'pixel_values': model_inputs["pixel_values"],
        'image_grid_thw': model_inputs["image_grid_thw"],
        'ground_truth': ground_truth
    }

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 1
NUM_WORKERS = 2

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    collate_fn=training_collate_fn,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    persistent_workers=True,
)
eval_loader = DataLoader(
    eval_dataset,
    batch_size=BATCH_SIZE,
    collate_fn=evaluating_collate_fn,
    num_workers=NUM_WORKERS,
    pin_memory=True,
)

# %%
# %pip install -q lightning nltk

# %%
from lightning.pytorch.loggers import CometLogger
from google.colab import userdata

comet_logger = CometLogger(
    api_key=userdata.get("COMET_API_KEY"),
    project="diagrams2sql",
    workspace="dvnguyen02",
)
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: keras, tensorflow, sklearn, torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/dvnguyen02/diagrams2sql/0c8d590852184640a82a6f56f0869170

# %%
import lightning as L
import json
from torch.optim import AdamW

class RealSchemaTrainer(L.LightningModule):
    """Lightning module based on training.py approach"""

    def __init__(self, model, processor, config):
        super().__init__()
        self.model = model
        self.processor = processor
        self.config = config

    def training_step(self, batch):
        outputs = self.model(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            pixel_values=batch["pixel_values"],
            image_grid_thw=batch["image_grid_thw"],
            labels=batch["labels"],
        )
        loss = outputs.loss
        self.log("train_loss", loss, logger=True, prog_bar=True)
        return loss

    def validation_step(self, batch):
        ground_truths = batch["ground_truth"]

        generated_ids = self.model.generate(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            pixel_values=batch["pixel_values"],
            image_grid_thw=batch["image_grid_thw"],
            max_new_tokens=256,  # Reduced for memory
            do_sample=False,
            temperature=1.0,
        )

        # Trim input tokens from generated output
        trimmed_generated_ids = [
            out_ids[len(in_ids):] for in_ids, out_ids in zip(batch["input_ids"], generated_ids)
        ]

        generated_json = self.processor.batch_decode(
            trimmed_generated_ids,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False,
        )

        # Improved evaluation metric from training.py
        scores = []
        for i, (generated, ground_truth) in enumerate(zip(generated_json, ground_truths)):
            try:
                # Try to parse both as JSON to check structure similarity
                gen_json = json.loads(generated.strip())
                gt_json = json.loads(ground_truth.strip())

                # Check if both have tables and relationships keys
                has_tables = "tables" in gen_json and "tables" in gt_json
                has_relationships = "relationships" in gen_json and "relationships" in gt_json

                if has_tables and has_relationships:
                    # Simple structural similarity
                    gen_table_count = len(gen_json.get("tables", []))
                    gt_table_count = len(gt_json.get("tables", []))
                    table_score = min(gen_table_count, gt_table_count) / max(gen_table_count, gt_table_count, 1)

                    gen_rel_count = len(gen_json.get("relationships", []))
                    gt_rel_count = len(gt_json.get("relationships", []))
                    rel_score = min(gen_rel_count, gt_rel_count) / max(gen_rel_count, gt_rel_count, 1)

                    score = (table_score + rel_score) / 2
                else:
                    score = 0.1

            except (json.JSONDecodeError, KeyError):
                # Fall back to string similarity if JSON parsing fails
                score = 0.05 if any(word in generated.lower() for word in ["table", "column", "relationship"]) else 0.0

            scores.append(score)

            # Log some examples for debugging
            if i < 1:  # Log first example only
                print(f"\nExample {i}:")
                print(f"Generated (first 150 chars): {generated[:150]}...")
                print(f"Ground truth (first 150 chars): {ground_truth[:150]}...")
                print(f"Score: {score:.3f}")

        accuracy = sum(scores) / len(scores)
        self.log("val_accuracy", accuracy, logger=True, prog_bar=True, batch_size=len(scores))
        return scores

    def configure_optimizers(self):
        optimizer = AdamW(self.model.parameters(), lr=self.config.get("lr"))
        return optimizer

# %%
config = {
    "max_epochs": 6,
    "batch_size": 1,
    "lr": 1e-4,
    "check_val_every_n_epoch": 2,
    "gradient_clip_val": 1.0,
    "accumulate_grad_batches": 8,
    "num_nodes": 1,
    "warmup_steps": 50,
    "result_path": "real_schema_model",
    "gradient_checkpointing ": True
}

# %%
model_module = RealSchemaTrainer(model, processor, config)

# %%
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.callbacks import Callback

# Monitor val_accuracy (higher is better) instead of edit distance
early_stopping_callback = EarlyStopping(
    monitor="val_accuracy", patience=4, verbose=False, mode="max"
)

class SaveCheckpoint(Callback):
    def __init__(self, result_path):
        self.result_path = result_path
        self.epoch = 0

    def on_train_epoch_end(self, trainer, pl_module):
        checkpoint_path = f"{self.result_path}/{self.epoch}"
        os.makedirs(checkpoint_path, exist_ok=True)

        pl_module.processor.save_pretrained(checkpoint_path)
        pl_module.model.save_pretrained(checkpoint_path)
        print(f"Checkpoint saved at {checkpoint_path}")

        self.epoch += 1

    def on_train_end(self, trainer, pl_module):
        checkpoint_path = f"{self.result_path}/latest"
        os.makedirs(checkpoint_path, exist_ok=True)

        pl_module.processor.save_pretrained(checkpoint_path)
        pl_module.model.save_pretrained(checkpoint_path)
        print(f"(Train Ended) -- Checkpoint saved at {checkpoint_path}")

# %%
trainer = L.Trainer(
    accelerator="gpu" if torch.cuda.is_available() else "cpu",
    devices=1,
    max_epochs=config.get("max_epochs"),
    check_val_every_n_epoch=config.get("check_val_every_n_epoch"),
    accumulate_grad_batches=config.get("accumulate_grad_batches"),
    gradient_clip_val=config.get("gradient_clip_val"),
    log_every_n_steps=5,
    limit_val_batches=10,
    callbacks=[early_stopping_callback, SaveCheckpoint(config.get("result_path"))],
    logger=comet_logger,
    precision="bf16-mixed",
)
# Out:
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# INFO: Using bfloat16 Automatic Mixed Precision (AMP)
# INFO:lightning.pytorch.utilities.rank_zero:Using bfloat16 Automatic Mixed Precision (AMP)
# INFO: 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:lightning.pytorch.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
print("Starting training with real schema data...")
trainer.fit(model_module, train_loader, eval_loader)
# Out:
# INFO: You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO:lightning.pytorch.utilities.rank_zero:You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name  | Type                 | Params | Mode
# -------------------------------------------------------
# 0 | model | PeftModelForCausalLM | 3.8 B  | train
# -------------------------------------------------------
# 7.4 M     Trainable params
# 3.8 B     Non-trainable params
# 3.8 B     Total params
# 15,047.983Total estimated model params size (MB)
# 1442      Modules in train mode
# 875       Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name  | Type                 | Params | Mode
# -------------------------------------------------------
# 0 | model | PeftModelForCausalLM | 3.8 B  | train
# -------------------------------------------------------
# 7.4 M     Trainable params
# 3.8 B     Non-trainable params
# 3.8 B     Total params
# 15,047.983Total estimated model params size (MB)
# 1442      Modules in train mode
# 875       Modules in eval mode
# Starting training with real schema data...
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Example 0:
# Generated (first 150 chars): opportunities...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.000
#
# Example 0:
# Generated (first 150 chars): ...
# Ground truth (first 150 chars): {"domain": "library", "source": "programmatic", "tables": [{"name": "books", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.000
# Training: |          | 0/? [00:00<?, ?it/s]
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# Checkpoint saved at real_schema_model/0
# Validation: |          | 0/? [00:00<?, ?it/s]
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "library", "source": "programmatic", "tables": [{"name": "books", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "library", "source": "programmatic", "tables": [{"name": "books", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key"...
# Ground truth (first 150 chars): {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key"...
# Ground truth (first 150 chars): {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "ecommerce", "source": "programmatic", "tables": [{"name": "users", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "ecommerce", "source": "programmatic", "tables": [{"name": "users", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
# Checkpoint saved at real_schema_model/1
# Checkpoint saved at real_schema_model/2
# Validation: |          | 0/? [00:00<?, ?it/s]
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "library", "source": "programmatic", "tables": [{"name": "books", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "library", "source": "programmatic", "tables": [{"name": "books", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key"...
# Ground truth (first 150 chars): {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key"...
# Ground truth (first 150 chars): {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "ecommerce", "source": "programmatic", "tables": [{"name": "users", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "ecommerce", "source": "programmatic", "tables": [{"name": "users", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
# Checkpoint saved at real_schema_model/3
# Checkpoint saved at real_schema_model/4
# Validation: |          | 0/? [00:00<?, ?it/s]
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "library", "source": "programmatic", "tables": [{"name": "books", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "library", "source": "programmatic", "tables": [{"name": "books", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key"...
# Ground truth (first 150 chars): {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key"...
# Ground truth (first 150 chars): {"domain": "hospital", "source": "programmatic", "tables": [{"name": "patients", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": tr...
# Ground truth (first 150 chars): {"domain": "crm", "source": "programmatic", "tables": [{"name": "customers", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"nam...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "school", "source": "programmatic", "tables": [{"name": "students", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
#
# Example 0:
# Generated (first 150 chars): assistant
# {"domain": "ecommerce", "source": "programmatic", "tables": [{"name": "users", "columns": [{"name": "id", "type": "INTEGER", "primary_key": ...
# Ground truth (first 150 chars): {"domain": "ecommerce", "source": "programmatic", "tables": [{"name": "users", "columns": [{"name": "id", "type": "INTEGER", "primary_key": true}, {"n...
# Score: 0.050
# INFO: `Trainer.fit` stopped: `max_epochs=6` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=6` reached.
# Checkpoint saved at real_schema_model/5
# (Train Ended) -- Checkpoint saved at real_schema_model/latest

# %%
from pathlib import Path

print("Saving final model...")
final_model_path = Path(config["result_path"]) / "final_model"
final_model_path.mkdir(parents=True, exist_ok=True)

model_module.model.save_pretrained(final_model_path)
processor.save_pretrained(final_model_path)

# Save training metadata
training_info = {
    "model_name": MODEL_ID,
    "quantization": "none",
    "batch_size": config["batch_size"],
    "accumulate_grad_batches": config["accumulate_grad_batches"],
    "effective_batch_size": config["batch_size"] * config["accumulate_grad_batches"],
    "learning_rate": config["lr"],
    "max_epochs": config["max_epochs"],
    "train_samples": len(train_dataset),
    "eval_samples": len(eval_dataset),
}

with open(f"{config['result_path']}/training_info.json", 'w') as f:
    json.dump(training_info, f, indent=2)

print(f"✅ Training complete! Model saved to {final_model_path}")

# ADD THIS for permanent storage:
from google.colab import drive
drive.mount('/content/drive')
print("Backing up to Google Drive...")
# !cp -r {config["result_path"]} /content/drive/MyDrive/
print("✅ Model backed up to Google Drive!")
# Out:
# Saving final model...
# ✅ Training complete! Model saved to real_schema_model/final_model
# Mounted at /content/drive
# Backing up to Google Drive...
# ✅ Model backed up to Google Drive!

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from huggingface_hub import create_repo

# Optional: Create repo if it doesn't exist yet
repo_name = "zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2"
create_repo(repo_name, private=True, exist_ok=True)  # set private=False if you want it public

# Load from local and push
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(final_model_path)
processor = AutoProcessor.from_pretrained(final_model_path)

model.push_to_hub(repo_name)
processor.push_to_hub(repo_name)
# Out:
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/29.5M [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2/commit/92b4c5c62da82b332a05eea58387cd44a98db6a0', commit_message='Upload processor', commit_description='', oid='92b4c5c62da82b332a05eea58387cd44a98db6a0', pr_url=None, repo_url=RepoUrl('https://huggingface.co/zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2'), pr_revision=None, pr_num=None)

# %%
from transformers import AutoProcessor, Qwen2_5_VLForConditionalGeneration
import torch
from PIL import Image
import json

# Load the model and processor from the Hugging Face Hub
model_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL"
processor = AutoProcessor.from_pretrained(model_id)
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(model_id, torch_dtype=torch.bfloat16, device_map="auto")

# Load a sample image
sample_image_path = "generated_diagrams/images/schema_0000.png"
image = Image.open(sample_image_path).convert("RGB")

# Prepare the prompt
prompt = "Extract data in JSON format"
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image", "image": image},
            {"type": "text", "text": prompt}
        ]
    }
]

# Process the inputs
text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
inputs = processor(text=[text], images=[image], return_tensors="pt").to("cuda")

# Generate the output
generated_ids = model.generate(
    inputs["input_ids"],
    pixel_values=inputs["pixel_values"],
    attention_mask=inputs["attention_mask"],
    image_grid_thw=inputs["image_grid_thw"],
    max_new_tokens=512,
    do_sample=False
)

# Decode the output
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

# Print the generated JSON
print(generated_text)

# %%
from transformers import AutoProcessor, Qwen2_5_VLForConditionalGeneration
import torch
from PIL import Image
import json
from IPython.display import display

# Load the model and processor from the Hugging Face Hub
model_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL"
processor = AutoProcessor.from_pretrained(model_id)
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(model_id, torch_dtype=torch.bfloat16, device_map="auto")

# Load a sample image.
# Note: You may need to upload 'real_diagrams.zip' and unzip it first for this to work.
sample_image_path = "generated_diagrams/images/schema_0000.png"
try:
    image = Image.open(sample_image_path).convert("RGB")

    # --- Display the image ---
    print("--- Input Image ---")
    display(image)

    # Prepare the prompt
    prompt = "Extract data in JSON format"
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "image": image},
                {"type": "text", "text": prompt}
            ]
        }
    ]

    # Process the inputs
    text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = processor(text=[text], images=[image], return_tensors="pt").to("cuda")

    # Generate the output
    generated_ids = model.generate(
        inputs["input_ids"],
        pixel_values=inputs["pixel_values"],
        attention_mask=inputs["attention_mask"],
        image_grid_thw=inputs["image_grid_thw"],
        max_new_tokens=1024,
        do_sample=False
    )

    # Decode the output
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

    # Print the generated JSON
    print("\n--- Generated Output ---")
    # Find the start of the JSON object
    json_start_index = generated_text.find('{')
    if json_start_index != -1:
        json_output = generated_text[json_start_index:]
        # Pretty-print the JSON
        parsed_json = json.loads(json_output)
        print(json.dumps(parsed_json, indent=2))
    else:
        print("Could not find JSON in the output.")
        print(generated_text)


except FileNotFoundError:
    print(f"Error: Sample image not found at {sample_image_path}")
    print("Please make sure the image file exists. You may need to upload and unzip 'real_diagrams.zip' first.")

# %% [markdown]
# # Task
# Benchmark the performance of the fine-tuned model `zodiac2525/Qwen2.5-VL-Diagrams2SQL` against the original base model `Qwen/Qwen2.5-VL-3B-Instruct` on the `eval_dataset` created during training. The benchmark should compare the generated JSON schemas from both models against the ground-truth schemas in the dataset. The comparison should focus on the accuracy of table and relationship counts. Finally, present the aggregated results in a pandas DataFrame for a clear side-by-side comparison.

# %% [markdown]
# ## Load models and processor
#
# ### Subtask:
# Load both the fine-tuned and base models from the Hugging Face Hub, along with the processor.

# %% [markdown]
# **Reasoning**:
# I will now load the fine-tuned and base models from the Hugging Face Hub, along with the processor, as per the instructions. This involves importing the necessary libraries, defining the model IDs, and then loading the processor and both models with the specified configurations.

# %%
from transformers import AutoProcessor, Qwen2_5_VLForConditionalGeneration
import torch

# Define model IDs
fine_tuned_model_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL"
base_model_id = "Qwen/Qwen2.5-VL-3B-Instruct"

# Load the processor from the fine-tuned model's repository
processor = AutoProcessor.from_pretrained(fine_tuned_model_id)

# Load the fine-tuned model
fine_tuned_model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    fine_tuned_model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

# Load the base model
base_model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    base_model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("Models and processor loaded successfully.")

# %% [markdown]
# ## Prepare benchmark data
#
# ### Subtask:
# Prepare the evaluation dataset for benchmarking by creating a DataLoader.

# %% [markdown]
# **Reasoning**:
# I need to create a `DataLoader` for the `eval_dataset` to prepare it for benchmarking. This involves importing the `DataLoader` class, instantiating it with the correct dataset, batch size, and collate function, and then printing the number of batches to confirm its creation.

# %%
from torch.utils.data import DataLoader

# Create a DataLoader for the evaluation dataset
benchmark_loader = DataLoader(
    eval_dataset,
    batch_size=1,  # Process one image at a time
    collate_fn=evaluating_collate_fn
)

# Print the number of batches to confirm
print(f"Number of batches in benchmark_loader: {len(benchmark_loader)}")

# %% [markdown]
# ## Define evaluation logic
#
# ### Subtask:
# Define the evaluation logic to compare the generated JSON schema with the ground-truth schema.

# %% [markdown]
# **Reasoning**:
# I will define the `evaluate_schema` function as requested in the instructions. This function will take the generated and ground truth JSON strings, parse them, and then calculate the accuracy of table and relationship counts.

# %%
import json

def evaluate_schema(generated_json, ground_truth_json):
    """
    Compares a generated schema with a ground-truth schema.

    Args:
        generated_json (str): The JSON string of the generated schema.
        ground_truth_json (str): The JSON string of the ground-truth schema.

    Returns:
        dict: A dictionary with table and relationship count accuracies.
    """
    try:
        gen_data = json.loads(generated_json)
        gt_data = json.loads(ground_truth_json)

        # Table count accuracy
        gen_tables = len(gen_data.get("tables", []))
        gt_tables = len(gt_data.get("tables", []))
        table_accuracy = min(gen_tables, gt_tables) / max(gen_tables, gt_tables, 1)

        # Relationship count accuracy
        gen_rels = len(gen_data.get("relationships", []))
        gt_rels = len(gt_data.get("relationships", []))
        relationship_accuracy = min(gen_rels, gt_rels) / max(gen_rels, gt_rels, 1)

        return {
            "table_count_accuracy": table_accuracy,
            "relationship_count_accuracy": relationship_accuracy
        }
    except json.JSONDecodeError:
        return {
            "table_count_accuracy": 0.0,
            "relationship_count_accuracy": 0.0
        }

# Example usage with dummy data to test the function
dummy_generated = '{"tables": [{}, {}], "relationships": [{}]}'
dummy_ground_truth = '{"tables": [{}, {}, {}], "relationships": [{}, {}]}'
scores = evaluate_schema(dummy_generated, dummy_ground_truth)
print(f"Example evaluation scores: {scores}")

# %% [markdown]
# ## Run inference and evaluate
#
# ### Subtask:
# Run inference on the benchmark data using both the fine-tuned and base models, and evaluate the results.

# %% [markdown]
# **Reasoning**:
# I will now implement the inference and evaluation loop. This involves creating the `run_inference` function to generate text from a given model and batch. Then, I will iterate through the `benchmark_loader`, run inference with both the fine-tuned and base models, and use the `evaluate_schema` function to compare the results against the ground truth. The scores will be stored in `fine_tuned_results` and `base_results` lists. Finally, I will print a confirmation message.

# %%
import json

fine_tuned_results = []
base_results = []

def run_inference(model, batch):
    generated_ids = model.generate(
        input_ids=batch["input_ids"].to(model.device),
        attention_mask=batch["attention_mask"].to(model.device),
        pixel_values=batch["pixel_values"].to(model.device),
        image_grid_thw=batch["image_grid_thw"].to(model.device),
        max_new_tokens=1024,
        do_sample=False,
    )

    decoded_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

    # Extract JSON part
    try:
        # Find the start of the JSON object
        json_start_index = decoded_text.find('{')
        if json_start_index != -1:
            json_output = decoded_text[json_start_index:]
            # Validate if it's a complete JSON
            json.loads(json_output)
            return json_output
    except json.JSONDecodeError:
        pass

    return "{}" # Return empty JSON if parsing fails or no JSON is found

for batch in benchmark_loader:
    ground_truth_json = batch["ground_truth"][0]

    # Inference and evaluation for fine-tuned model
    fine_tuned_generated_json = run_inference(fine_tuned_model, batch)
    fine_tuned_scores = evaluate_schema(fine_tuned_generated_json, ground_truth_json)
    fine_tuned_results.append(fine_tuned_scores)

    # Inference and evaluation for base model
    base_generated_json = run_inference(base_model, batch)
    base_scores = evaluate_schema(base_generated_json, ground_truth_json)
    base_results.append(base_scores)

print("Inference and evaluation complete.")

# %% [markdown]
# ## Summarize and display results
#
# ### Subtask:
# Aggregate the evaluation scores for both models and display them in a pandas DataFrame for a clear side-by-side comparison.

# %% [markdown]
# **Reasoning**:
# Aggregate the evaluation scores for both models and display them in a pandas DataFrame for a clear side-by-side comparison.

# %%
import pandas as pd

# Convert lists of dictionaries to DataFrames
fine_tuned_df = pd.DataFrame(fine_tuned_results)
base_df = pd.DataFrame(base_results)

# Calculate the mean scores
fine_tuned_mean_scores = fine_tuned_df.mean()
base_mean_scores = base_df.mean()

# Create a summary DataFrame
summary_data = {
    'Fine-tuned Model': fine_tuned_mean_scores,
    'Base Model': base_mean_scores
}
summary_df = pd.DataFrame(summary_data)

# Rename index for clarity
summary_df = summary_df.rename(index={
    'table_count_accuracy': 'Table Count Accuracy',
    'relationship_count_accuracy': 'Relationship Count Accuracy'
})

# Display the summary DataFrame
display(summary_df)

# %% [markdown]
# ## Summary:
#
# ### Q&A
# **How does the fine-tuned model (`zodiac2525/Qwen2.5-VL-Diagrams2SQL`) perform compared to the base model (`Qwen/Qwen2.5-VL-3B-Instruct`) on the diagram-to-SQL task?**
#
# The fine-tuned model significantly outperforms the base model. The fine-tuned model achieved an average **Table Count Accuracy** of approximately **84.0%** and an average **Relationship Count Accuracy** of approximately **83.6%**. In contrast, the base model failed to produce any valid JSON output, resulting in an accuracy of **0%** for both metrics.
#
# ### Data Analysis Key Findings
# *   The fine-tuned model demonstrates a strong capability in accurately identifying the number of tables and relationships from diagram images, achieving high accuracy scores.
# *   The base model, without specific fine-tuning for this task, is unable to generate the required JSON schema structure, leading to a complete failure in the evaluation.
# *   The evaluation process successfully benchmarked both models across 81 samples from the evaluation dataset.
# *   The performance metrics were aggregated into a clear summary table, highlighting the stark difference in capabilities between the two models.
#
# ### Insights or Next Steps
# *   Fine-tuning is crucial for adapting vision-language models to specialized tasks like converting database diagrams into structured JSON schemas.
# *   Future work could involve expanding the evaluation to include the correctness of table names, column names, and relationship details, not just their counts, for a more comprehensive benchmark.

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from huggingface_hub import HfApi

# Define the repository ID
repo_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2"
final_model_path = Path(config["result_path"]) / "final_model"

# Push the model and processor to the Hub
print(f"Pushing model to {repo_id}...")
model.push_to_hub(repo_id)
processor.push_to_hub(repo_id)

print(f"✅ Model successfully pushed to {repo_id}")
# Out:
# Pushing model to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2...
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# ✅ Model successfully pushed to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from pathlib import Path

# Define the repository ID
repo_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2"
final_model_path = Path(config["result_path"]) / "final_model"

# Load the model and processor from the final saved path
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(final_model_path)
processor = AutoProcessor.from_pretrained(final_model_path)

# Push the model to the Hub with sharding
print(f"Pushing sharded model to {repo_id}...")
model.push_to_hub(
    repo_id,
    max_shard_size="1GB",
    commit_message="feat: Upload sharded model weights"
)

# Push the processor as well
print(f"Pushing processor to {repo_id}...")
processor.push_to_hub(
    repo_id,
    commit_message="feat: Upload processor for sharded model"
)

print(f"✅ Sharded model successfully pushed to {repo_id}")
# Out:
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Pushing sharded model to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2...
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# Pushing processor to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2...
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# ✅ Sharded model successfully pushed to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2

# %%
from huggingface_hub import HfApi
from pathlib import Path

# Define the repository ID and local model path
repo_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2"
local_model_path = Path(config["result_path"]) / "final_model"

# Initialize the HfApi
api = HfApi()

# Upload the folder contents to the Hub
print(f"Uploading files from {local_model_path} to {repo_id}...")
api.upload_folder(
    folder_path=local_model_path,
    repo_id=repo_id,
    repo_type="model",
    commit_message="feat: Upload sharded model weights and processor"
)

print(f"✅ Files successfully uploaded to {repo_id}")
# Out:
# Uploading files from real_schema_model/final_model to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2...
# adapter_model.safetensors:   0%|          | 0.00/29.5M [00:00<?, ?B/s]
# ✅ Files successfully uploaded to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from peft import PeftModel
from pathlib import Path
import torch

# Define model IDs and paths
base_model_id = "Qwen/Qwen2.5-VL-3B-Instruct"
adapter_model_path = Path(config["result_path"]) / "final_model"
repo_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2"

# Load the base model
base_model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    base_model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

# Load the LoRA adapter and merge it with the base model
merged_model = PeftModel.from_pretrained(base_model, adapter_model_path).merge_and_unload()

# Push the merged model to the Hub with sharding
print(f"Pushing merged model to {repo_id}...")
merged_model.push_to_hub(
    repo_id,
    max_shard_size="1GB",
    commit_message="feat: Upload full merged model weights"
)

# Load the processor and push it as well
processor = AutoProcessor.from_pretrained(adapter_model_path)
print(f"Pushing processor to {repo_id}...")
processor.push_to_hub(
    repo_id,
    commit_message="feat: Upload processor for merged model"
)

print(f"✅ Full merged model successfully pushed to {repo_id}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Pushing merged model to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2...
# README.md: 0.00B [00:00, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/970M [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/970M [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/989M [00:00<?, ?B/s]
# Upload 8 LFS files:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/662M [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/981M [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/970M [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/970M [00:00<?, ?B/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/998M [00:00<?, ?B/s]
# Pushing processor to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2...
# ✅ Full merged model successfully pushed to zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2

# %% [markdown]
# # Task
# Benchmark the performance of the fine-tuned model `zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2` against the original base model `Qwen/Qwen2.5-VL-3B-Instruct` on a small subset (20 samples) of the `eval_dataset`.

# %% [markdown]
# ## Load models and processor
#
# ### Subtask:
# Load the fine-tuned model (`zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2`), the base model (`Qwen/Qwen2.5-VL-3B-Instruct`), and the processor from the Hugging Face Hub.

# %% [markdown]
# **Reasoning**:
# I will now load the fine-tuned and base models from the Hugging Face Hub, along with the processor, as per the instructions. This involves importing the necessary libraries, defining the model IDs, and then loading the processor and both models with the specified configurations.

# %%
from transformers import AutoProcessor, Qwen2_5_VLForConditionalGeneration
import torch

# Define model IDs
fine_tuned_model_id = "zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2"
base_model_id = "Qwen/Qwen2.5-VL-3B-Instruct"

# Load the processor from the fine-tuned model's repository
processor = AutoProcessor.from_pretrained(fine_tuned_model_id)

# Load the fine-tuned model
fine_tuned_model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    fine_tuned_model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

# Load the base model
base_model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    base_model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("Models and processor loaded successfully.")
# Out:
# preprocessor_config.json:   0%|          | 0.00/791 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# video_preprocessor_config.json:   0%|          | 0.00/907 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# adapter_config.json:   0%|          | 0.00/860 [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/29.5M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Models and processor loaded successfully.

# %% [markdown]
# ## Prepare benchmark data
#
# ### Subtask:
# Create a smaller subset of the `eval_dataset` (20 samples) and create a `DataLoader` for it.

# %% [markdown]
# **Reasoning**:
# I will now create a smaller subset of the `eval_dataset` with 20 samples, as instructed. I will then create a `DataLoader` for this subset. This will prepare the data for the benchmarking task.

# %%
from torch.utils.data import Subset, DataLoader

# Create a smaller subset of the eval_dataset
eval_subset = Subset(eval_dataset, range(20))

# Create a DataLoader for the subset
benchmark_loader = DataLoader(
    eval_subset,
    batch_size=1,
    collate_fn=evaluating_collate_fn
)

# Print the number of batches to confirm
print(f"Number of batches in benchmark_loader: {len(benchmark_loader)}")
# Out:
# Number of batches in benchmark_loader: 20

# %% [markdown]
# ## Define evaluation logic
#
# ### Subtask:
# Define the evaluation logic to compare the generated JSON schema with the ground-truth schema.

# %% [markdown]
# **Reasoning**:
# I will define the `evaluate_schema` function as requested in the instructions. This function will take the generated and ground truth JSON strings, parse them, and then calculate the accuracy of table and relationship counts.

# %%
import json

def evaluate_schema(generated_json, ground_truth_json):
    """
    Compares a generated schema with a ground-truth schema.

    Args:
        generated_json (str): The JSON string of the generated schema.
        ground_truth_json (str): The JSON string of the ground-truth schema.

    Returns:
        dict: A dictionary with table and relationship count accuracies.
    """
    try:
        gen_data = json.loads(generated_json)
        gt_data = json.loads(ground_truth_json)

        # Table count accuracy
        gen_tables = len(gen_data.get("tables", []))
        gt_tables = len(gt_data.get("tables", []))
        table_accuracy = min(gen_tables, gt_tables) / max(gen_tables, gt_tables, 1)

        # Relationship count accuracy
        gen_rels = len(gen_data.get("relationships", []))
        gt_rels = len(gt_data.get("relationships", []))
        relationship_accuracy = min(gen_rels, gt_rels) / max(gen_rels, gt_rels, 1)

        return {
            "table_count_accuracy": table_accuracy,
            "relationship_count_accuracy": relationship_accuracy
        }
    except json.JSONDecodeError:
        return {
            "table_count_accuracy": 0.0,
            "relationship_count_accuracy": 0.0
        }

# Example usage with dummy data to test the function
dummy_generated = '{"tables": [{}, {}], "relationships": [{}]}'
dummy_ground_truth = '{"tables": [{}, {}, {}], "relationships": [{}, {}]}'
scores = evaluate_schema(dummy_generated, dummy_ground_truth)
print(f"Example evaluation scores: {scores}")
# Out:
# Example evaluation scores: {'table_count_accuracy': 0.6666666666666666, 'relationship_count_accuracy': 0.5}

# %% [markdown]
# ## Run inference and evaluate
#
# ### Subtask:
# Run inference on the benchmark data using both the fine-tuned and base models, and evaluate the results.

# %% [markdown]
# **Reasoning**:
# I will now implement the inference and evaluation loop. This involves creating the `run_inference` function to generate text from a given model and batch. Then, I will iterate through the `benchmark_loader`, run inference with both the fine-tuned and base models, and use the `evaluate_schema` function to compare the results against the ground truth. The scores will be stored in `fine_tuned_results` and `base_results` lists. Finally, I will print a confirmation message.

# %%
import json
from tqdm import tqdm

fine_tuned_results = []
base_results = []

def run_inference(model, batch):
    generated_ids = model.generate(
        input_ids=batch["input_ids"].to(model.device),
        attention_mask=batch["attention_mask"].to(model.device),
        pixel_values=batch["pixel_values"].to(model.device),
        image_grid_thw=batch["image_grid_thw"].to(model.device),
        max_new_tokens=1024,
        do_sample=False,
    )

    decoded_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

    # Extract JSON part
    try:
        # Find the start of the JSON object
        json_start_index = decoded_text.find('{')
        if json_start_index != -1:
            json_output = decoded_text[json_start_index:]
            # Validate if it's a complete JSON
            json.loads(json_output)
            return json_output
    except json.JSONDecodeError:
        pass

    return "{}" # Return empty JSON if parsing fails or no JSON is found

for batch in tqdm(benchmark_loader, desc="Benchmarking models"):
    ground_truth_json = batch["ground_truth"][0]

    # Inference and evaluation for fine-tuned model
    fine_tuned_generated_json = run_inference(fine_tuned_model, batch)
    fine_tuned_scores = evaluate_schema(fine_tuned_generated_json, ground_truth_json)
    fine_tuned_results.append(fine_tuned_scores)

    # Inference and evaluation for base model
    base_generated_json = run_inference(base_model, batch)
    base_scores = evaluate_schema(base_generated_json, ground_truth_json)
    base_results.append(base_scores)

print("Inference and evaluation complete.")
# Out:
# Benchmarking models:   0%|          | 0/20 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:   5%|▌         | 1/20 [01:07<21:29, 67.84s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  10%|█         | 2/20 [02:20<21:14, 70.83s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  15%|█▌        | 3/20 [03:32<20:13, 71.36s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  20%|██        | 4/20 [04:43<18:57, 71.12s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  25%|██▌       | 5/20 [05:55<17:54, 71.61s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  30%|███       | 6/20 [07:07<16:41, 71.54s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  35%|███▌      | 7/20 [08:18<15:28, 71.44s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  40%|████      | 8/20 [09:26<14:02, 70.19s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  45%|████▌     | 9/20 [10:22<12:03, 65.75s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  50%|█████     | 10/20 [11:32<11:11, 67.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  55%|█████▌    | 11/20 [12:43<10:14, 68.27s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  60%|██████    | 12/20 [13:55<09:16, 69.59s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  65%|██████▌   | 13/20 [15:01<07:58, 68.40s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  70%|███████   | 14/20 [16:11<06:52, 68.82s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  75%|███████▌  | 15/20 [17:19<05:42, 68.57s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  80%|████████  | 16/20 [18:25<04:31, 67.97s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  85%|████████▌ | 17/20 [19:36<03:26, 68.75s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  90%|█████████ | 18/20 [20:44<02:16, 68.41s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models:  95%|█████████▌| 19/20 [21:55<01:09, 69.18s/it]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Benchmarking models: 100%|██████████| 20/20 [23:03<00:00, 69.20s/it]
# Inference and evaluation complete.

# %% [markdown]
# **Reasoning**:
# The inference and evaluation are complete. The next step is to aggregate the results and display them in a pandas DataFrame for comparison, as per the original main task. This involves calculating the mean scores for both models and presenting them in a well-formatted table.

# %%
import pandas as pd

# Convert lists of dictionaries to DataFrames
fine_tuned_df = pd.DataFrame(fine_tuned_results)
base_df = pd.DataFrame(base_results)

# Calculate the mean scores
fine_tuned_mean_scores = fine_tuned_df.mean()
base_mean_scores = base_df.mean()

# Create a summary DataFrame
summary_data = {
    'Fine-tuned Model': fine_tuned_mean_scores,
    'Base Model': base_mean_scores
}
summary_df = pd.DataFrame(summary_data)

# Rename index for clarity
summary_df = summary_df.rename(index={
    'table_count_accuracy': 'Table Count Accuracy',
    'relationship_count_accuracy': 'Relationship Count Accuracy'
})

# Display the summary DataFrame
display(summary_df)
# Out:
#                              Fine-tuned Model  Base Model
# Table Count Accuracy                 0.891667         0.0
# Relationship Count Accuracy          0.900000         0.0

# %% [markdown]
# ## Summarize and display results
#
# ### Subtask:
# Aggregate the evaluation scores for both models and display them in a pandas DataFrame for a clear side-by-side comparison.

# %% [markdown]
# **Reasoning**:
# I will now aggregate the evaluation scores for both models and display them in a pandas DataFrame. This involves converting the results lists to DataFrames, calculating the mean scores, creating a summary DataFrame, renaming the index for clarity, and finally displaying the result.

# %%
import pandas as pd

# Convert lists of dictionaries to DataFrames
fine_tuned_df = pd.DataFrame(fine_tuned_results)
base_df = pd.DataFrame(base_results)

# Calculate the mean scores
fine_tuned_mean_scores = fine_tuned_df.mean()
base_mean_scores = base_df.mean()

# Create a summary DataFrame
summary_data = {
    'Fine-tuned Model': fine_tuned_mean_scores,
    'Base Model': base_mean_scores
}
summary_df = pd.DataFrame(summary_data)

# Rename index for clarity
summary_df = summary_df.rename(index={
    'table_count_accuracy': 'Table Count Accuracy',
    'relationship_count_accuracy': 'Relationship Count Accuracy'
})

# Display the summary DataFrame
display(summary_df)
# Out:
#                              Fine-tuned Model  Base Model
# Table Count Accuracy                 0.891667         0.0
# Relationship Count Accuracy          0.900000         0.0

# %% [markdown]
# ## Findings
#
# *   The fine-tuned model (`zodiac2525/Qwen2.5-VL-Diagrams2SQL-v2`) achieved significantly higher accuracy in identifying the number of tables (approximately 89.2%) and relationships (90.0%) compared to the base model.
# *   The base model (`Qwen/Qwen2.5-VL-3B-Instruct`) was unable to produce valid output for this task, resulting in 0.0% accuracy for both table and relationship counts on the benchmark subset.
#
# ### Next Steps
# *   Future steps could involve evaluating the models on more granular metrics, such as the correctness of table and relationship names, attributes, and types, beyond just the counts.
